# %% [markdown]
# <a href="https://colab.research.google.com/github/arinajman/personal/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Same as project 1 but converting the dates from the Gregorian calendar to the Hebrew calendar

# %%
# !pip install pyluach

import pyluach
from pyluach import dates

# %%
#help(pyluach)

# %%
#dir(pyluach)

# %%
#help(dates)

# %%
#dir(pyluach.dates)

# %%
#help(dates.GregorianDate)

# %%
#dir(dates.GregorianDate)

# %%
#help(dates.HebrewDate)

# %%
#dir(dates.HebrewDate)

# %%
import yfinance as yf
import pandas as pd
import datetime

# %%
tic = yf.Ticker('^GSPC') #índice S&P500 ^GSPC
print(tic)
tic_data=tic.history(period='max')
print(tic_data.info)
# Out:
# yfinance.Ticker object <^GSPC>
# <bound method DataFrame.info of                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-04-17 00:00:00-04:00  5305.450195  5328.310059  5255.580078  5282.700195
# 2025-04-21 00:00:00-04:00  5232.939941  5232.939941  5101.629883  5158.200195
# 2025-04-22 00:00:00-04:00  5207.669922  5309.609863  5207.669922  5287.759766
# 2025-04-23 00:00:00-04:00  5395.919922  5469.689941  5356.169922  5375.859863
# ...

# %%
tic_data.index=tic_data.index.date
tic_data
# Out:
#                    Open         High          Low        Close      Volume  \
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2025-04-17  5305.450195  5328.310059  5255.580078  5282.700195  4714880000
# 2025-04-21  5232.939941  5232.939941  5101.629883  5158.200195  4226340000
# 2025-04-22  5207.669922  5309.609863  5207.669922  5287.759766  4666950000
# 2025-04-23  5395.919922  5469.689941  5356.169922  5375.859863  5371390000
# 2025-04-24  5381.379883  5489.399902  5371.959961  5484.770020  3138911000
#
#             Dividends  Stock Splits
# ...

# %%
tic_data.index
# Out:
# Index([1927-12-30, 1928-01-03, 1928-01-04, 1928-01-05, 1928-01-06, 1928-01-09,
#        1928-01-10, 1928-01-11, 1928-01-12, 1928-01-13,
#        ...
#        2025-04-10, 2025-04-11, 2025-04-14, 2025-04-15, 2025-04-16, 2025-04-17,
#        2025-04-21, 2025-04-22, 2025-04-23, 2025-04-24],
#       dtype='object', length=24444)

# %%
ind_heb=[]

# %%
for i in list(range(len(tic_data))):
    d=tic_data.index[i]
    ind_heb.append(dates.HebrewDate.from_pydate(d))
first=ind_heb[:5]
last=ind_heb[-5:]
print('ind_heb first values:',first)
print('ind_heb last values:',last)
# Out:
# ind_heb first values: [HebrewDate(5688, 10, 6), HebrewDate(5688, 10, 10), HebrewDate(5688, 10, 11), HebrewDate(5688, 10, 12), HebrewDate(5688, 10, 13)]
# ind_heb last values: [HebrewDate(5785, 1, 19), HebrewDate(5785, 1, 23), HebrewDate(5785, 1, 24), HebrewDate(5785, 1, 25), HebrewDate(5785, 1, 26)]

# %%
tic_heb=tic_data.copy()
tic_heb.index=ind_heb
tic_heb
# Out:
#                    Open         High          Low        Close      Volume  \
# 5688-10-06    17.660000    17.660000    17.660000    17.660000           0
# 5688-10-10    17.760000    17.760000    17.760000    17.760000           0
# 5688-10-11    17.719999    17.719999    17.719999    17.719999           0
# 5688-10-12    17.549999    17.549999    17.549999    17.549999           0
# 5688-10-13    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 5785-01-19  5305.450195  5328.310059  5255.580078  5282.700195  4714880000
# 5785-01-23  5232.939941  5232.939941  5101.629883  5158.200195  4226340000
# 5785-01-24  5207.669922  5309.609863  5207.669922  5287.759766  4666950000
# 5785-01-25  5395.919922  5469.689941  5356.169922  5375.859863  5371390000
# 5785-01-26  5381.379883  5489.399902  5371.959961  5484.770020  3138911000
#
#             Dividends  Stock Splits
# ...

# %%
start=tic_heb.index[0]
start
# Out:
# HebrewDate(5688, 10, 6)

# %%
print(start.year,type(start.year))
print(start.month,type(start.month))
print(start.day,type(start.day))
# Out:
# 5688 <class 'int'>
# 10 <class 'int'>
# 6 <class 'int'>

# %%
sy=start.year
print(sy,type(sy))
# Out:
# 5688 <class 'int'>

# %%
tic_year_close=pd.DataFrame(columns=['Value'])
tic_year_close.index.name='Year'
tic_year_close
# Out:
# Empty DataFrame
# Columns: [Value]
# Index: []

# %%
for i in list(range(len(tic_heb))):
    index_date=tic_heb.index[i]
    heb_year=index_date.year
    if heb_year!=sy:
        yprev=tic_heb.index[i-1].year
        value=round(tic_heb['Close'].iloc[i-1],2)
        tic_year_close.loc[yprev]=[value]
        sy=heb_year
tic_year_close
# Out:
#         Value
# Year
# 5688    21.14
# 5689    28.65
# 5690    20.17
# 5691    12.69
# 5692     8.08
# ...       ...
# 5780  3319.47
# 5781  4535.43
# 5782  3693.23
# 5783  4450.32
# 5784  5709.54
#
# [97 rows x 1 columns]

# %%
tic_year_close['Variation (%)']=list(range(len(tic_year_close)))
tic_year_close['Variation (%)']=tic_year_close['Variation (%)'].astype(float)
#tic_year_close

# %%
for q in list(range(len(tic_year_close))):
    year_to_access = tic_year_close.index[q]
    if q==0:
        tic_year_close.loc[year_to_access,'Variation (%)']=round((tic_year_close.loc[year_to_access,'Value']/tic_heb.iloc[0]['Close']-1)*100,1)
    else:
        year_previous = tic_year_close.index[q-1]
        tic_year_close.loc[year_to_access,'Variation (%)']=round((tic_year_close.loc[year_to_access,'Value']/tic_year_close.loc[year_previous,'Value']-1)*100,1)
tic_year_close
# Out:
#         Value  Variation (%)
# Year
# 5688    21.14           19.7
# 5689    28.65           35.5
# 5690    20.17          -29.6
# 5691    12.69          -37.1
# 5692     8.08          -36.3
# ...       ...            ...
# 5780  3319.47           12.1
# 5781  4535.43           36.6
# 5782  3693.23          -18.6
# 5783  4450.32           20.5
# 5784  5709.54           28.3
#
# [97 rows x 2 columns]

# %%
print(sum(tic_year_close['Variation (%)']>0),'positive years')
print(sum(tic_year_close['Variation (%)']==0),'zero returns years')
print(sum(tic_year_close['Variation (%)']<0),'negative years')
# Out:
# 66 positive years
# 0 zero returns years
# 31 negative years
