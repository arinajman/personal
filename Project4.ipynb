# %% [markdown]
# <a href="https://colab.research.google.com/github/arinajman/personal/blob/main/Project4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Obtener datos del US Treasury Bill a 1 año

# %%
# !pip install fredapi
# Out:
# Requirement already satisfied: fredapi in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fredapi) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.17.0)

# %%
import pandas as pd
from pandas_datareader import data as pdr
import datetime
from fredapi import Fred
import os

# %%
#help(os)
#dir(os)
#help(os.environ)

# %%
# Establecer la variable de entorno (solo para la sesión actual)
os.environ['API_KEY'] = '' #'TU_CLAVE_SECRETA'
# Acceder a la variable de entorno en tu código
api_key = os.environ.get('API_KEY')

if api_key:
    print(f"La clave API es: {api_key[:5]}...") # Muestra solo los primeros caracteres por seguridad
    # Utiliza api_key en tus llamadas a la API
else:
    print("La clave API no está configurada como variable de entorno.")
# Out:
# La clave API es: cd3a4...

# %%
#help(pdr)
#dir(pdr)
#help(pdr.DataReader)
#dir(pdr.DataReader)

# %%
#help(Fred)
#dir(Fred)

# %%
fred=Fred(api_key)
fred

# %%
# Ticker para la tasa de inflación anual (CPI)
ticker = 'FPCPITOTLZGUSA'

# %%
fred.get_series_info(ticker)
# Out:
# id                                                              FPCPITOTLZGUSA
# realtime_start                                                      2025-04-16
# realtime_end                                                        2025-04-16
# title                         Inflation, consumer prices for the United States
# observation_start                                                   1960-01-01
# observation_end                                                     2024-01-01
# frequency                                                               Annual
# frequency_short                                                              A
# units                                                                  Percent
# units_short                                                                  %
# seasonal_adjustment                                    Not Seasonally Adjusted
# seasonal_adjustment_short                                                  NSA
# last_updated                                            2025-04-16 13:53:02-05
# popularity                                                                  85
# notes                        Inflation as measured by the consumer price in...
# dtype: object

# %%
print('observation_start:',fred.get_series_info(ticker)['observation_start'],type(fred.get_series_info(ticker)['observation_start']))
year_start = int(fred.get_series_info(ticker)['observation_start'][:4])
print('year_start:',year_start,type(year_start))
month_start = int(fred.get_series_info(ticker)['observation_start'][5:7])
print('month_start:',month_start,type(month_start))
day_start = int(fred.get_series_info(ticker)['observation_start'][8:10])
print('day_start:',day_start,type(day_start))
start=datetime.datetime(year_start,month_start,day_start)
print('start:',start,type(start))
# Out:
# observation_start: 1960-01-01 <class 'str'>
# year_start: 1960 <class 'int'>
# month_start: 1 <class 'int'>
# day_start: 1 <class 'int'>
# start: 1960-01-01 00:00:00 <class 'datetime.datetime'>

# %%
df = pdr.DataReader(ticker, 'fred',start)
df
# Out:
#             FPCPITOTLZGUSA
# DATE
# 1960-01-01        1.457976
# 1961-01-01        1.070724
# 1962-01-01        1.198773
# 1963-01-01        1.239669
# 1964-01-01        1.278912
# ...                    ...
# 2020-01-01        1.233584
# 2021-01-01        4.697859
# 2022-01-01        8.002800
# 2023-01-01        4.116338
# 2024-01-01        2.949525
#
# [65 rows x 1 columns]

# %%
df_final = df
df_final.index=df_final.index.year
df_final
# Out:
#       FPCPITOTLZGUSA
# DATE
# 1960        1.457976
# 1961        1.070724
# 1962        1.198773
# 1963        1.239669
# 1964        1.278912
# ...              ...
# 2020        1.233584
# 2021        4.697859
# 2022        8.002800
# 2023        4.116338
# 2024        2.949525
#
# [65 rows x 1 columns]

# %%
# prompt: cambiar el nombre de la columna de df_final por 'Inflation (%)'

df_final = df_final.rename(columns={df_final.columns[0]: 'Inflation (%)'})
df_final
# Out:
#       Inflation (%)
# DATE
# 1960       1.457976
# 1961       1.070724
# 1962       1.198773
# 1963       1.239669
# 1964       1.278912
# ...             ...
# 2020       1.233584
# 2021       4.697859
# 2022       8.002800
# 2023       4.116338
# 2024       2.949525
#
# [65 rows x 1 columns]

# %%
# prompt: redondear los datos de df_final a 2 cifras

df_final = df_final.round(2)
df_final
# Out:
#       Inflation (%)
# DATE
# 1960           1.46
# 1961           1.07
# 1962           1.20
# 1963           1.24
# 1964           1.28
# ...             ...
# 2020           1.23
# 2021           4.70
# 2022           8.00
# 2023           4.12
# 2024           2.95
#
# [65 rows x 1 columns]

# %%
from google.colab import drive
import pickle

drive.mount('/content/drive')

# Asumo que ya tienes tu DataFrame 'df3' como resultado de tus operaciones.
# Si no es así, asegúrate de que la variable 'df3' contenga tu DataFrame.

# Define la ruta donde quieres guardar el DataFrame serializado
ruta_guardado3_pkl = '/content/drive/MyDrive/df3.pkl'

# Serializa y guarda el DataFrame
with open(ruta_guardado3_pkl, 'wb') as archivo:
    pickle.dump(df_final, archivo)

print(f"DataFrame 3 serializado y guardado en: {ruta_guardado3_pkl}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# DataFrame 3 serializado y guardado en: /content/drive/MyDrive/df3.pkl
