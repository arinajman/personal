# %% [markdown]
# <a href="https://colab.research.google.com/github/arinajman/personal/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Get historical data from Yahoo Finance and analyze results on an annual basis.

# %%
#!pip install --upgrade yfinance

# %%
import yfinance as yf
import pandas as pd
import datetime
import time

# %%
tic = yf.Ticker('^GSPC') #índice S&P500 ^GSPC
print(tic)
#dir(tic)
#tic.info
tic_data=tic.history(period='max')
print(type(tic_data))
display(tic_data)
tic_data.describe()
# Out:
# yfinance.Ticker object <^GSPC>
# <class 'pandas.core.frame.DataFrame'>
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-05-09 00:00:00-04:00  5679.649902  5691.689941  5644.149902  5659.910156
# 2025-05-12 00:00:00-04:00  5807.200195  5845.370117  5786.080078  5844.189941
# 2025-05-13 00:00:00-04:00  5854.149902  5906.640137  5845.020020  5886.549805
# 2025-05-14 00:00:00-04:00  5896.740234  5906.549805  5872.109863  5892.580078
# ...

# %%
tic_data.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-05-02 00:00:00-04:00', '2025-05-05 00:00:00-04:00',
#                '2025-05-06 00:00:00-04:00', '2025-05-07 00:00:00-04:00',
#                '2025-05-08 00:00:00-04:00', '2025-05-09 00:00:00-04:00',
#                '2025-05-12 00:00:00-04:00', '2025-05-13 00:00:00-04:00',
#                '2025-05-14 00:00:00-04:00', '2025-05-15 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24459, freq=None)

# %%
ind=tic_data.index
ind.date
# Out:
# array([datetime.date(1927, 12, 30), datetime.date(1928, 1, 3),
#        datetime.date(1928, 1, 4), ..., datetime.date(2025, 5, 13),
#        datetime.date(2025, 5, 14), datetime.date(2025, 5, 15)],
#       dtype=object)

# %%
new_ind=ind.date
tic_data.index=new_ind
tic_data
# Out:
#                    Open         High          Low        Close      Volume  \
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2025-05-09  5679.649902  5691.689941  5644.149902  5659.910156  4645090000
# 2025-05-12  5807.200195  5845.370117  5786.080078  5844.189941  6014580000
# 2025-05-13  5854.149902  5906.640137  5845.020020  5886.549805  5516290000
# 2025-05-14  5896.740234  5906.549805  5872.109863  5892.580078  5233450000
# 2025-05-15  5869.819824  5924.209961  5865.160156  5916.930176  4991290000
#
#             Dividends  Stock Splits
# ...

# %%
tic_data['Year'] = pd.DatetimeIndex(tic_data.index).year
tic_close=tic_data.groupby('Year').last()
new_df=tic_close[['Close']]
new_df
# Out:
#             Close
# Year
# 1927    17.660000
# 1928    24.350000
# 1929    21.450001
# 1930    15.340000
# 1931     8.120000
# ...           ...
# 2021  4766.180176
# 2022  3839.500000
# 2023  4769.830078
# 2024  5881.629883
# 2025  5916.930176
#
# [99 rows x 1 columns]

# %%
#display(tic_data.iloc[23000])
#display(tic_data.loc[datetime.date(2019,7,29)])
#display(tic_data.index[23000])

# %%
tic_data.index
# Out:
# Index([1927-12-30, 1928-01-03, 1928-01-04, 1928-01-05, 1928-01-06, 1928-01-09,
#        1928-01-10, 1928-01-11, 1928-01-12, 1928-01-13,
#        ...
#        2025-05-02, 2025-05-05, 2025-05-06, 2025-05-07, 2025-05-08, 2025-05-09,
#        2025-05-12, 2025-05-13, 2025-05-14, 2025-05-15],
#       dtype='object', length=24459)

# %%
start=tic_data.index[0]
print(start,type(start))
sy=start.year
print(sy,type(sy))
# Out:
# 1927-12-30 <class 'datetime.date'>
# 1927 <class 'int'>

# %%
tic_year_close=pd.DataFrame(columns=['Value'])
tic_year_close.index.name='Year'
tic_year_close
# Out:
# Empty DataFrame
# Columns: [Value]
# Index: []

# %%
len(tic_year_close)
# Out:
# 0

# %%
tic_data.index[4]
# Out:
# datetime.date(1928, 1, 6)

# %%
for i in list(range(len(tic_data))):
    da=tic_data.index[i]
    ye=da.year
    if ye!=sy:
        yprev=tic_data.index[i-1].year
        value=round(tic_data['Close'].iloc[i-1],2)
        tic_year_close.loc[yprev]=[value]
        sy=ye
tic_year_close
# Out:
#         Value
# Year
# 1927    17.66
# 1928    24.35
# 1929    21.45
# 1930    15.34
# 1931     8.12
# ...       ...
# 2020  3756.07
# 2021  4766.18
# 2022  3839.50
# 2023  4769.83
# 2024  5881.63
#
# [98 rows x 1 columns]

# %%
for q in list(range(len(tic_year_close))):
    year_to_access = tic_year_close.index[q]
    if q==0:
        tic_year_close.loc[year_to_access,'Variation (%)']=round((tic_year_close.loc[year_to_access,'Value']/tic_data.iloc[0]['Close']-1)*100,1)
    else:
        year_previous = tic_year_close.index[q-1]
        tic_year_close.loc[year_to_access,'Variation (%)']=round((tic_year_close.loc[year_to_access,'Value']/tic_year_close.loc[year_previous,'Value']-1)*100,1)
tic_year_close
# Out:
#         Value  Variation (%)
# Year
# 1927    17.66            0.0
# 1928    24.35           37.9
# 1929    21.45          -11.9
# 1930    15.34          -28.5
# 1931     8.12          -47.1
# ...       ...            ...
# 2020  3756.07           16.3
# 2021  4766.18           26.9
# 2022  3839.50          -19.4
# 2023  4769.83           24.2
# 2024  5881.63           23.3
#
# [98 rows x 2 columns]

# %% [markdown]
# The current code obtains the annual S&P500 index value. However, when investing in the index through an ETF, investors also receive dividends. Therefore, to calculate the total investment return completely, the code should be modified to incorporate these dividends.

# %% [markdown]
# For this, we will obtain the paid dividend data from the website https://www.multpl.com/s-p-500-dividend-yield/table/by-year

# %%
dividend = {'Year': [1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
        'Value (%)': [5.49, 5.92, 7.47, 7.27, 6.86, 8.38, 5.85, 5.22, 4.07, 4.45, 5.32, 5.48, 6.18, 7.14, 4.62, 3.9, 4.74, 4.47, 4.14, 4.78, 4.07, 4.36, 5.67, 4.88, 4.4, 4.27, 3.79, 3.54, 3.49, 4.37, 4.03, 4.1, 5.33, 3.76, 3.46, 4.07, 6.7, 4.43, 4.27, 5.19, 5.16, 5.12, 5.97, 5.71, 4.54, 5.71, 10.15, 7.22, 5.94, 7.49, 6.29, 5.81, 6.2, 5.41, 4.82, 5.11, 4.41, 3.67, 4.53, 6.32, 9.72, 7.33, 4.41, 4.86, 3.6, 4.22, 7.26, 4.02, 5.01, 6.36, 8.11, 6.2, 5.31, 4.89, 3.81, 4.69, 5.59, 6.12, 6.89, 7.44, 6.02, 5.41, 5.84, 4.4, 3.61, 3.75, 4.44, 3.27, 3.1, 3.43, 2.82, 3.4, 3.07, 2.98, 2.97, 3.53, 3.06, 2.88, 3.47, 3.49, 3.1, 2.68, 3.57, 5.37, 4.15, 3.87, 4.98, 5.28, 5.24, 4.61, 5.36, 4.93, 4.31, 4.58, 3.81, 3.33, 3.66, 3.53, 3.17, 3.68, 3.14, 2.84, 2.7, 2.89, 2.24, 2, 1.61, 1.36, 1.17, 1.22, 1.37, 1.79, 1.61, 1.62, 1.76, 1.76, 1.87, 3.23, 2.02, 1.83, 2.13, 2.2, 1.94, 1.92, 2.11, 2.03, 1.84, 2.09, 1.83, 1.58, 1.29, 1.71, 1.5, 1.24],
        }
df = pd.DataFrame(dividend)
df = df.set_index('Year')
df
# Out:
#       Value (%)
# Year
# 1871       5.49
# 1872       5.92
# 1873       7.47
# 1874       7.27
# 1875       6.86
# ...         ...
# 2020       1.58
# 2021       1.29
# 2022       1.71
# 2023       1.50
# 2024       1.24
#
# [154 rows x 1 columns]

# %%
merged_df = pd.merge(tic_year_close, df, left_index=True, right_index=True, how='left')
merged_df = merged_df.rename(columns={'Value': 'SP500', 'Value (%)': 'Dividend (%)'})
merged_df.iloc[0, merged_df.columns.get_loc('Dividend (%)')] = 0
merged_df
# Out:
#         SP500  Variation (%)  Dividend (%)
# Year
# 1927    17.66            0.0          0.00
# 1928    24.35           37.9          3.67
# 1929    21.45          -11.9          4.53
# 1930    15.34          -28.5          6.32
# 1931     8.12          -47.1          9.72
# ...       ...            ...           ...
# 2020  3756.07           16.3          1.58
# 2021  4766.18           26.9          1.29
# 2022  3839.50          -19.4          1.71
# 2023  4769.83           24.2          1.50
# 2024  5881.63           23.3          1.24
#
# [98 rows x 3 columns]

# %%
merged_df['Dividend ($)'] = round(merged_df['SP500'] * (merged_df['Dividend (%)'] / 100),2)
merged_df
# Out:
#         SP500  Variation (%)  Dividend (%)  Dividend ($)
# Year
# 1927    17.66            0.0          0.00          0.00
# 1928    24.35           37.9          3.67          0.89
# 1929    21.45          -11.9          4.53          0.97
# 1930    15.34          -28.5          6.32          0.97
# 1931     8.12          -47.1          9.72          0.79
# ...       ...            ...           ...           ...
# 2020  3756.07           16.3          1.58         59.35
# 2021  4766.18           26.9          1.29         61.48
# 2022  3839.50          -19.4          1.71         65.66
# 2023  4769.83           24.2          1.50         71.55
# 2024  5881.63           23.3          1.24         72.93
#
# [98 rows x 4 columns]

# %% [markdown]
# Next, I will generate a new column to reflect the total value of the S&P500, adding the annual dividends to the index value. To simplify this exercise, I will assume that the dividends are paid at the end of the year, using the index value already available in the table. (In reality, dividends are distributed quarterly).

# %%
merged_df['Total Value'] = 0
merged_df['Total Value'] = merged_df['Total Value'].astype(float)
for i in list(range(len(merged_df))):
    if i==0:
      merged_df.iloc[i, merged_df.columns.get_loc('Total Value')] = merged_df.iloc[i, merged_df.columns.get_loc('SP500')] + merged_df.iloc[i, merged_df.columns.get_loc('Dividend ($)')]
    else:
      merged_df.iloc[i, merged_df.columns.get_loc('Total Value')] = merged_df.iloc[(i-1), merged_df.columns.get_loc('Total Value')] * ( 1 + merged_df.iloc[i, merged_df.columns.get_loc('Variation (%)')]/100) + merged_df.iloc[i, merged_df.columns.get_loc('Dividend ($)')]
merged_df['Total Value'] = round(merged_df['Total Value'],2)
merged_df
# Out:
#         SP500  Variation (%)  Dividend (%)  Dividend ($)  Total Value
# Year
# 1927    17.66            0.0          0.00          0.00        17.66
# 1928    24.35           37.9          3.67          0.89        25.24
# 1929    21.45          -11.9          4.53          0.97        23.21
# 1930    15.34          -28.5          6.32          0.97        17.56
# 1931     8.12          -47.1          9.72          0.79        10.08
# ...       ...            ...           ...           ...          ...
# 2020  3756.07           16.3          1.58         59.35     16858.55
# 2021  4766.18           26.9          1.29         61.48     21454.98
# 2022  3839.50          -19.4          1.71         65.66     17358.37
# 2023  4769.83           24.2          1.50         71.55     21630.65
# 2024  5881.63           23.3          1.24         72.93     26743.52
#
# [98 rows x 5 columns]

# %%
for q in list(range(len(merged_df))):
    year_to_access = merged_df.index[q]
    if q==0:
        merged_df.loc[year_to_access,'Total Variation (%)']=round((merged_df.loc[year_to_access,'Total Value']/tic_data.iloc[0]['Close']-1)*100,1)
    else:
        year_previous = merged_df.index[q-1]
        merged_df.loc[year_to_access,'Total Variation (%)']=round((merged_df.loc[year_to_access,'Total Value']/merged_df.loc[year_previous,'Total Value']-1)*100,1)
merged_df
# Out:
#         SP500  Variation (%)  Dividend (%)  Dividend ($)  Total Value  \
# Year
# 1927    17.66            0.0          0.00          0.00        17.66
# 1928    24.35           37.9          3.67          0.89        25.24
# 1929    21.45          -11.9          4.53          0.97        23.21
# 1930    15.34          -28.5          6.32          0.97        17.56
# 1931     8.12          -47.1          9.72          0.79        10.08
# ...       ...            ...           ...           ...          ...
# 2020  3756.07           16.3          1.58         59.35     16858.55
# 2021  4766.18           26.9          1.29         61.48     21454.98
# 2022  3839.50          -19.4          1.71         65.66     17358.37
# 2023  4769.83           24.2          1.50         71.55     21630.65
# 2024  5881.63           23.3          1.24         72.93     26743.52
#
#       Total Variation (%)
# Year
# 1927                  0.0
# 1928                 42.9
# 1929                 -8.0
# ...

# %%
#pd.set_option("display.max_rows", None)  # Show all rows
#display(merged_df)

# %%
#pd.set_option("display.max_rows", 10)  # Show only first and last 5 rows
#display(merged_df)

# %%
print(sum(merged_df['Total Variation (%)']>0),'positive years')
print(sum(merged_df['Total Variation (%)']==0),'zero returns years')
print(sum(merged_df['Total Variation (%)']<0),'negative years')
# Out:
# 68 positive years
# 1 zero returns years
# 29 negative years

# %%
from google.colab import drive
import pickle

drive.mount('/content/drive')

# Asumo que ya tienes tu DataFrame 'df1' como resultado de tus operaciones.
# Si no es así, asegúrate de que la variable 'df1' contenga tu DataFrame.

# Define la ruta donde quieres guardar el DataFrame serializado
ruta_guardado1_pkl = '/content/drive/MyDrive/df1.pkl'

# Serializa y guarda el DataFrame
with open(ruta_guardado1_pkl, 'wb') as archivo:
    pickle.dump(merged_df, archivo)

print(f"DataFrame 1 serializado y guardado en: {ruta_guardado1_pkl}")
# Out:
# Mounted at /content/drive
# DataFrame 1 serializado y guardado en: /content/drive/MyDrive/df1.pkl
