# %% [markdown]
# <a href="https://colab.research.google.com/github/arinajman/personal/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Get historical data from Yahoo Finance and analyze results on an annual basis.

# %%
import yfinance as yf
import pandas as pd
import datetime

# %%
tic = yf.Ticker('^GSPC') #índice S&P500 ^GSPC
print(tic)
#dir(tic)
#tic.info
tic.history(period='max')
# Out:
# yfinance.Ticker object <^GSPC>
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
# 2025-04-17 00:00:00-04:00  5305.450195  5328.310059  5255.580078  5282.700195
# 2025-04-21 00:00:00-04:00  5232.939941  5232.939941  5101.629883  5158.200195
# 2025-04-22 00:00:00-04:00  5207.669922  5309.609863  5207.669922  5287.759766
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2025-04-15 00:00:00-04:00  4317110000        0.0           0.0
# 2025-04-16 00:00:00-04:00  4607750000        0.0           0.0
# 2025-04-17 00:00:00-04:00  4714880000        0.0           0.0
# 2025-04-21 00:00:00-04:00  4226340000        0.0           0.0
# 2025-04-22 00:00:00-04:00  3049425000        0.0           0.0
#
# [24442 rows x 7 columns]

# %%
tic_data=tic.history(period='max')
#dir(tic_data)
print(tic_data.info)
print(tic_data.dtypes)
# Out:
# <bound method DataFrame.info of                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-04-15 00:00:00-04:00  5411.990234  5450.410156  5386.439941  5396.629883
# 2025-04-16 00:00:00-04:00  5335.750000  5367.240234  5220.790039  5275.700195
# 2025-04-17 00:00:00-04:00  5305.450195  5328.310059  5255.580078  5282.700195
# 2025-04-21 00:00:00-04:00  5232.939941  5232.939941  5101.629883  5158.200195
# 2025-04-22 00:00:00-04:00  5207.669922  5309.609863  5207.669922  5287.759766
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2025-04-15 00:00:00-04:00  4317110000        0.0           0.0
# 2025-04-16 00:00:00-04:00  4607750000        0.0           0.0
# 2025-04-17 00:00:00-04:00  4714880000        0.0           0.0
# 2025-04-21 00:00:00-04:00  4226340000        0.0           0.0
# 2025-04-22 00:00:00-04:00  3049425000        0.0           0.0
#
# [24442 rows x 7 columns]>
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
tic_data.iloc[23000]
# Out:
# Open            3.024470e+03
# High            3.025610e+03
# Low             3.014300e+03
# Close           3.020970e+03
# Volume          3.224490e+09
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2019-07-29 00:00:00-04:00, dtype: float64

# %%
tic_data.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-04-08 00:00:00-04:00', '2025-04-09 00:00:00-04:00',
#                '2025-04-10 00:00:00-04:00', '2025-04-11 00:00:00-04:00',
#                '2025-04-14 00:00:00-04:00', '2025-04-15 00:00:00-04:00',
#                '2025-04-16 00:00:00-04:00', '2025-04-17 00:00:00-04:00',
#                '2025-04-21 00:00:00-04:00', '2025-04-22 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24442, freq=None)

# %%
ind=tic_data.index
#dir(ind)

# %%
ind.date
# Out:
# array([datetime.date(1927, 12, 30), datetime.date(1928, 1, 3),
#        datetime.date(1928, 1, 4), ..., datetime.date(2025, 4, 17),
#        datetime.date(2025, 4, 21), datetime.date(2025, 4, 22)],
#       dtype=object)

# %%
new_ind=ind.date
new_ind
# Out:
# array([datetime.date(1927, 12, 30), datetime.date(1928, 1, 3),
#        datetime.date(1928, 1, 4), ..., datetime.date(2025, 4, 17),
#        datetime.date(2025, 4, 21), datetime.date(2025, 4, 22)],
#       dtype=object)

# %%
tic_data.index=new_ind
tic_data
# Out:
#                    Open         High          Low        Close      Volume  \
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2025-04-15  5411.990234  5450.410156  5386.439941  5396.629883  4317110000
# 2025-04-16  5335.750000  5367.240234  5220.790039  5275.700195  4607750000
# 2025-04-17  5305.450195  5328.310059  5255.580078  5282.700195  4714880000
# 2025-04-21  5232.939941  5232.939941  5101.629883  5158.200195  4226340000
# 2025-04-22  5207.669922  5309.609863  5207.669922  5287.759766  3049425000
#
#             Dividends  Stock Splits
# 1927-12-30        0.0           0.0
# 1928-01-03        0.0           0.0
# 1928-01-04        0.0           0.0
# 1928-01-05        0.0           0.0
# 1928-01-06        0.0           0.0
# ...               ...           ...
# 2025-04-15        0.0           0.0
# 2025-04-16        0.0           0.0
# 2025-04-17        0.0           0.0
# 2025-04-21        0.0           0.0
# 2025-04-22        0.0           0.0
#
# [24442 rows x 7 columns]

# %%
tic_data.iloc[23000]
# Out:
# Open            3.024470e+03
# High            3.025610e+03
# Low             3.014300e+03
# Close           3.020970e+03
# Volume          3.224490e+09
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2019-07-29, dtype: float64

# %%
tic_data.loc[datetime.date(2019,7,29)]
# Out:
# Open            3.024470e+03
# High            3.025610e+03
# Low             3.014300e+03
# Close           3.020970e+03
# Volume          3.224490e+09
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2019-07-29, dtype: float64

# %%
tic_data.index[23000]
# Out:
# datetime.date(2019, 7, 29)

# %%
tic_data.index
# Out:
# Index([1927-12-30, 1928-01-03, 1928-01-04, 1928-01-05, 1928-01-06, 1928-01-09,
#        1928-01-10, 1928-01-11, 1928-01-12, 1928-01-13,
#        ...
#        2025-04-08, 2025-04-09, 2025-04-10, 2025-04-11, 2025-04-14, 2025-04-15,
#        2025-04-16, 2025-04-17, 2025-04-21, 2025-04-22],
#       dtype='object', length=24442)

# %%
start=tic_data.index[0]
print(start,type(start))
sy=start.year
print(sy,type(sy))
# Out:
# 1927-12-30 <class 'datetime.date'>
# 1927 <class 'int'>

# %%
tic_year_close=pd.DataFrame(columns=['Value'])
tic_year_close.index.name='Year'
tic_year_close
# Out:
# Empty DataFrame
# Columns: [Value]
# Index: []

# %%
len(tic_year_close)
# Out:
# 0

# %%
tic_data.index[4]
# Out:
# datetime.date(1928, 1, 6)

# %%
for i in list(range(len(tic_data))):
    da=tic_data.index[i]
    ye=da.year
    if ye!=sy:
        yprev=tic_data.index[i-1].year
        value=round(tic_data['Close'].iloc[i-1],2)
        tic_year_close.loc[yprev]=[value]
        sy=ye
tic_year_close
# Out:
#         Value
# Year
# 1927    17.66
# 1928    24.35
# 1929    21.45
# 1930    15.34
# 1931     8.12
# ...       ...
# 2020  3756.07
# 2021  4766.18
# 2022  3839.50
# 2023  4769.83
# 2024  5881.63
#
# [98 rows x 1 columns]

# %%
tic_year_close['Variation (%)']=list(range(len(tic_year_close)))
tic_year_close['Variation (%)']=tic_year_close['Variation (%)'].astype(float)
tic_year_close
# Out:
#         Value  Variation (%)
# Year
# 1927    17.66            0.0
# 1928    24.35            1.0
# 1929    21.45            2.0
# 1930    15.34            3.0
# 1931     8.12            4.0
# ...       ...            ...
# 2020  3756.07           93.0
# 2021  4766.18           94.0
# 2022  3839.50           95.0
# 2023  4769.83           96.0
# 2024  5881.63           97.0
#
# [98 rows x 2 columns]

# %%
for q in list(range(len(tic_year_close))):
    year_to_access = tic_year_close.index[q]
    if q==0:
        tic_year_close.loc[year_to_access,'Variation (%)']=0
    else:
        year_previous = tic_year_close.index[q-1]
        tic_year_close.loc[year_to_access,'Variation (%)']=round((tic_year_close.loc[year_to_access,'Value']/tic_year_close.loc[year_previous,'Value']-1)*100,1)
tic_year_close
# Out:
#         Value  Variation (%)
# Year
# 1927    17.66            0.0
# 1928    24.35           37.9
# 1929    21.45          -11.9
# 1930    15.34          -28.5
# 1931     8.12          -47.1
# ...       ...            ...
# 2020  3756.07           16.3
# 2021  4766.18           26.9
# 2022  3839.50          -19.4
# 2023  4769.83           24.2
# 2024  5881.63           23.3
#
# [98 rows x 2 columns]

# %%
#print(tic_year_close.to_string())
print(sum(tic_year_close['Variation (%)']>0),'positive years')
print(sum(tic_year_close['Variation (%)']==0),'zero returns years')
print(sum(tic_year_close['Variation (%)']<0),'negative years')
# Out:
# 65 positive years
# 3 zero returns years
# 30 negative years
